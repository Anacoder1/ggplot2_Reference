# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
ggplot(mtcars, aes(factor(cyl), fill = factor(vs))) +
  geom_bar(position = "dodge2")
# Out:
# plot without title

# %%
# By default, dodging with 'position_dodge2()' preserves the
# width of each element. You can choose to preserve the total
# width with:

ggplot(mtcars, aes(factor(cyl), fill = factor(vs))) +
  geom_bar(position = position_dodge(preserve = "total"))
# Out:
# plot without title

# %%
ggplot(diamonds, aes(price, fill = cut)) +
  geom_histogram(position = "dodge2")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# See ?geom_bar for more examples

# In this case, a frequency polygon is probably a better choice

ggplot(diamonds, aes(price, colour = cut)) +
  geom_freqpoly()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# Dodging with various widths ---------------------------------

# To dodge items with different widths, you need to be explicit

df <- data.frame(x = c("a", "a", "b", "b"), y = 2:5,
                 g = rep(1:2, 2))
p <- ggplot(df, aes(x, y, group = g)) +
  geom_col(position = "dodge", fill = "grey50", 
           colour = "black")
p
# Out:
# plot without title

# %%
# A line range has no width:

p +
  geom_linerange(aes(ymin = y - 1, ymax = y + 1), 
                 position = "dodge")
# Out:
# Warning message:
# "Width not defined. Set with `position_dodge(width = ?)`"
# plot without title

# %%
# So you must explicitly specify the width

p + 
  geom_linerange(aes(ymin = y - 1, ymax = y + 1),
                 position = position_dodge(width = 0.9))
# Out:
# plot without title

# %%
# The same principle applies to error bars, which are usually
# narrower than the bars

p +
  geom_errorbar(aes(ymin = y - 1, ymax = y + 1),
                width = 0.2,
                position = "dodge")
# Out:
# plot without title

# %%
p +
  geom_errorbar(aes(ymin = y - 1, ymax = y + 1),
                width = 0.2,
                position = position_dodge(width = 0.9))
# Out:
# plot without title

# %%
# Box plots use position_dodge2() by default, and bars can
# use it too

ggplot(data = iris, aes(Species, Sepal.Length)) +
  geom_boxplot(aes(colour = Sepal.Width < 3.2))
# Out:
# plot without title

# %%
ggplot(data = iris, aes(Species, Sepal.Length)) +
  geom_boxplot(aes(colour = Sepal.Width < 3.2), 
               varwidth = TRUE)
# Out:
# plot without title

# %%
ggplot(mtcars, aes(factor(cyl), fill = factor(vs))) +
  geom_bar(position = position_dodge2(preserve = "single"))
# Out:
# plot without title

# %%
ggplot(mtcars, aes(factor(cyl), fill = factor(vs))) +
  geom_bar(position = position_dodge2(preserve = "total"))
# Out:
# plot without title
