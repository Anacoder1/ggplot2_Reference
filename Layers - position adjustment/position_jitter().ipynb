# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
# Jittering is useful when you have a discrete position, and a
# relatively small number of points take up as much space as
# a boxplot or a bar

ggplot(mpg, aes(class, hwy)) +
  geom_boxplot(colour = "grey50") +
  geom_jitter()
# Out:
# plot without title

# %%
# If the default jittering is too much, as in this plot:

ggplot(mtcars, aes(am, vs)) +
  geom_jitter()
# Out:
# plot without title

# %%
# You can adjust it in 2 ways

ggplot(mtcars, aes(am, vs)) +
  geom_jitter(width = 0.1, height = 0.1)
# Out:
# plot without title

# %%
ggplot(mtcars, aes(am, vs)) +
  geom_jitter(position = position_jitter(width = 0.1,
                                         height = 0.1))
# Out:
# plot without title

# %%
# Create a jitter object for reproducible jitter:

jitter <- position_jitter(width = 0.1, height = 0.1)

ggplot(mtcars, aes(am, vs)) +
  geom_point(position = jitter) +
  geom_point(position = jitter, color = "red",
             aes(am + 0.2, vs + 0.2))
# Out:
# plot without title
