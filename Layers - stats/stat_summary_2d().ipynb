# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
d <- ggplot(diamonds, aes(carat, depth, z = price))
d +
  stat_summary_2d()
# Out:
# plot without title

# %%
# Specifying function

d +
  stat_summary_2d(fun = function(x) sum(x ^ 2))
# Out:
# plot without title

# %%
d +
  stat_summary_2d(fun = var)
# Out:
# plot without title

# %%
d +
  stat_summary_2d(fun = "quantile", 
                  fun.args = list(probs = 0.1))
# Out:
# plot without title

# %%
if(requireNamespace("hexbin")) {
    d +
      stat_summary_hex()
}
# Out:
# Loading required namespace: hexbin
# plot without title
