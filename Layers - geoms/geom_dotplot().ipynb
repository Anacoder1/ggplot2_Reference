# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
ggplot(mtcars, aes(x = mpg)) + geom_dotplot()
# Out:
# `stat_bindot()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(mtcars, aes(x = mpg)) + geom_dotplot(binwidth = 1.5)
# Out:
# plot without title

# %%
# Using fixed - width bins

ggplot(mtcars, aes(x = mpg)) +
  geom_dotplot(method = "histodot", binwidth = 1.5)
# Out:
# plot without title

# %%
# Some other stacking methods

ggplot(mtcars, aes(x = mpg)) +
  geom_dotplot(binwidth = 1.5, stackdir = "center")
# Out:
# plot without title

# %%
ggplot(mtcars, aes(x = mpg)) +
  geom_dotplot(binwidth = 1.5, stackdir = "centerwhole")
# Out:
# plot without title

# %%
# y - axis isn't really meaningful, so hiding it

ggplot(mtcars, aes(x = mpg)) + 
  geom_dotplot(binwidth = 1.5) +
  scale_y_continuous(NULL, breaks = NULL)
# Out:
# plot without title

# %%
# Overlap dots vertically

ggplot(mtcars, aes(x = mpg)) + 
  geom_dotplot(binwidth = 1.5, stackratio = .7)
# Out:
# plot without title

# %%
# Expand dot diameter

ggplot(mtcars, aes(x = mpg)) +
  geom_dotplot(binwidth = 1.5, dotsize = 1.25)
# Out:
# plot without title

# %%
# Let's see examples with stacking along y - axis instead of x

ggplot(mtcars, aes(x = 1, y = mpg)) +
  geom_dotplot(binaxis = "y", stackdir = "center")
# Out:
# `stat_bindot()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(mtcars, aes(x = factor(cyl), y = mpg)) +
  geom_dotplot(binaxis = "y", stackdir = "center")
# Out:
# `stat_bindot()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(mtcars, aes(x = factor(cyl), y = mpg)) +
  geom_dotplot(binaxis = "y", stackdir = "centerwhole")
# Out:
# `stat_bindot()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(mtcars, aes(x = factor(vs), fill = factor(cyl), y = mpg)) +
  geom_dotplot(binaxis = "y", stackdir = "center", position = "dodge")
# Out:
# `stat_bindot()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# binpositions = "all" ensures that the bins are aligned 
# between groups

ggplot(mtcars, aes(x = factor(am), y = mpg)) +
  geom_dotplot(binaxis = "y", stackdir = "center",
               binpositions = "all")
# Out:
# `stat_bindot()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# Stacking multiple groups, with different fill

ggplot(mtcars, aes(x = mpg, fill = factor(cyl))) +
  geom_dotplot(stackgroups = TRUE, binwidth = 1, 
               binpositions = "all")
# Out:
# plot without title

# %%
ggplot(mtcars, aes(x = mpg, fill = factor(cyl))) +
  geom_dotplot(stackgroups = TRUE, binwidth = 1, 
               method = "histodot")
# Out:
# plot without title

# %%
ggplot(mtcars, aes(x = 1, y = mpg, fill = factor(cyl))) +
  geom_dotplot(binaxis = "y", stackgroups = TRUE,
               binwidth = 1, method = "histodot")
# Out:
# plot without title
