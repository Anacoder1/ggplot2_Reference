# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
p <- ggplot(mtcars, aes(wt, mpg)) +
  geom_point()
p
# Out:
# plot without title

# %%
p + geom_rug()
# Out:
# plot without title

# %%
p + geom_rug(sides = "b") # Rug on bottom only
# Out:
# plot without title

# %%
p + geom_rug(sides = "trbl") # All 4 sides
# Out:
# plot without title

# %%
# Use jittering to avoid overplotting for smaller datasets

ggplot(mpg, aes(displ, cty)) +
  geom_point() +
  geom_rug()
# Out:
# plot without title

# %%
ggplot(mpg, aes(displ, cty)) +
  geom_jitter() +
  geom_rug(alpha = 1/2, position = "jitter")
# Out:
# plot without title
