# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
m <- ggplot(mpg, aes(displ, 1 / hwy)) + geom_point()
m + geom_quantile()
# Out:
# Warning message:
# "package 'quantreg' was built under R version 3.5.1"Loading required package: SparseM
#
# Attaching package: 'SparseM'
#
# The following object is masked from 'package:base':
#
#     backsolve
#
# Smoothing formula not specified. Using: y ~ x
# plot without title

# %%
m + geom_quantile(quantiles = 0.5)
# Out:
# Smoothing formula not specified. Using: y ~ x
# plot without title

# %%
q10 <- seq(0.05, 0.95, by = 0.05)

m + geom_quantile(quantiles = q10)
# Out:
# Smoothing formula not specified. Using: y ~ x
# plot without title

# %%
# You can also use rqss to fit smooth quantiles

m + geom_quantile(method = "rqss")
# Out:
# Warning message:
# "package 'MatrixModels' was built under R version 3.5.1"Smoothing formula not specified. Using: y ~ qss(x, lambda = 1)
# plot without title

# %%
# Note that rqss doesn't pick a smoothing constant 
# automatically, so you'll need to tweak lambda yourself

m + geom_quantile(method = "rqss", lambda = 0.1)
# Out:
# Smoothing formula not specified. Using: y ~ qss(x, lambda = 0.1)
# plot without title

# %%
# Set aesthetics to fixed value

m + geom_quantile(colour = "red", size = 2, alpha = 0.5)
# Out:
# Smoothing formula not specified. Using: y ~ x
# plot without title
