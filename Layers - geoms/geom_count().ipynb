# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
ggplot(mpg, aes(cty, hwy)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(mpg, aes(cty, hwy)) +
  geom_count()
# Out:
# plot without title

# %%
# geom_count() is best used in tandem with scale_size_area()
# which ensures that counts of 0 would be given size 0. Doesn't
# make much difference here as the smallest count is already
# close to 0.

ggplot(mpg, aes(cty, hwy)) +
  geom_count() +
  scale_size_area()
# Out:
# plot without title

# %%
# Display proportions instead of counts - 
# By default, all categorical variables in the plot form the 
# groups.
# Specifying geom_count() without a group identifier leads to a 
# plot which is not much useful

d <- ggplot(diamonds, aes(x = cut, y = clarity)) 
d + geom_count(aes(size = stat(prop)))
# Out:
# plot without title

# %%
# To correct this problem and achieve a more desirable plot, 
# specify which group the proportion is to be calculated over.

d + geom_count(aes(size = stat(prop), group = 1)) +
  scale_size_area(max_size = 10)
# Out:
# plot without title

# %%
# Or group by x / y variables to have rows / columns sum to 1

d + geom_count(aes(size = stat(prop), group = cut)) +
  scale_size_area(max_size = 10)
# Out:
# plot without title

# %%
d + geom_count(aes(size = stat(prop), group = clarity)) +
  scale_size_area(max_size = 10)
# Out:
# plot without title
