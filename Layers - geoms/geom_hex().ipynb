# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
d <- ggplot(diamonds, aes(carat, price))
d + geom_hex()
# Out:
# plot without title

# %%
# The size of the bins can be controlled by specifying the
# number of bins in each direction

d + geom_hex(bins = 10)
# Out:
# plot without title

# %%
d + geom_hex(bins = 30)
# Out:
# plot without title

# %%
# Or by specifying the width of the bins

d + geom_hex(binwidth = c(1, 1000))
# Out:
# plot without title

# %%
d + geom_hex(binwidth = c(.1, 500))
# Out:
# plot without title
