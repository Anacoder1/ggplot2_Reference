# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"

# %%
p <- ggplot(mtcars, aes(factor(cyl), mpg))
p + geom_violin()
# Out:
# plot without title

# %%
p +
  geom_violin() +
  geom_jitter(height = 0, width = 0.1)
# Out:
# plot without title

# %%
# Scale maximum width proportional to sample size:

p + geom_violin(scale = "count")
# Out:
# plot without title

# %%
# Scale maximum width to 1 for all violins:

p +
  geom_violin(scale = "width")
# Out:
# plot without title

# %%
# Default is to trim violins to the range of the data.
# To disable:

p +
  geom_violin(trim = FALSE)
# Out:
# plot without title

# %%
# Use a smaller bandwidth for closer density fit (default is 1).

p +
  geom_violin(adjust = .5)
# Out:
# plot without title

# %%
# Adding aesthetic mappings
# Note that violins are automatically dodged when any
# aesthetic is a factor

p +
  geom_violin(aes(fill = cyl))
# Out:
# plot without title

# %%
p +
  geom_violin(aes(fill = factor(cyl)))
# Out:
# plot without title

# %%
p +
  geom_violin(aes(fill = factor(vs)))
# Out:
# plot without title

# %%
p +
  geom_violin(aes(fill = factor(am)))
# Out:
# plot without title

# %%
# Set aesthetics to fixed value

p +
  geom_violin(fill = "grey80", colour = "#3366FF")
# Out:
# plot without title

# %%
# Show quartiles

p +
  geom_violin(draw_quantiles = c(0.25, 0.5, 0.75))
# Out:
# plot without title

# %%
# Scales vs. coordinate transforms --------------------------

if(require("ggplot2movies")) {
#     Scale transformations occur before the density statistics
#     are computed. Coordinate transformations occur
#     afterwards. Observe the effect on the number of outliers.
    m <- ggplot(movies, aes(y = votes, x = rating, 
                            group = cut_width(rating, 0.5)))
    m + geom_violin()
}
# Out:
# Loading required package: ggplot2movies
# plot without title

# %%
 m + 
  geom_violin() + 
  scale_y_log10()
# Out:
# plot without title

# %%
m + 
  geom_violin() + 
  coord_trans(y = "log10")
# Out:
# plot without title

# %%
m + 
  geom_violin() + 
  scale_y_log10() + 
  coord_trans(y = "log10")
# Out:
# plot without title

# %%
# Violin plots with continuous x:
# Use the group aesthetic to group observations in violins

ggplot(movies, aes(year, budget)) +
  geom_violin()
# Out:
# Warning message:
# "Removed 53573 rows containing non-finite values (stat_ydensity)."
# plot without title

# %%
ggplot(movies, aes(year, budget)) +
  geom_violin(aes(group = cut_width(year, 10)), 
              scale = "width")
# Out:
# Warning message:
# "Removed 53573 rows containing non-finite values (stat_ydensity)."
# plot without title
