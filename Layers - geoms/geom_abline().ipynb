# %%
library(ggplot2)

p <- ggplot(mtcars, aes(wt, mpg)) + geom_point()

# Fixed values
p + geom_vline(xintercept = 5)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.1"
# plot without title

# %%
p + geom_vline(xintercept = 1:5)
# Out:
# plot without title

# %%
p + geom_hline(yintercept = 20)
# Out:
# plot without title

# %%
p + geom_abline() # invisible - outside the range of the data
# Out:
# plot without title

# %%
p + geom_abline(intercept = 20)
# Out:
# plot without title

# %%
# Calculating slope & intercept of line of best fit
coef(lm(mpg ~ wt, data = mtcars))
# Out:
# (Intercept)          wt
#   37.285126   -5.344472

# %%
p + geom_abline(intercept = 37, slope = -5)
# Out:
# plot without title

# %%
# This is easier to do with geom_smooth() :

p + geom_smooth(method = "lm", se = FALSE)
# Out:
# plot without title

# %%
# To show different lines in different facets, use aesthetics

p <- ggplot(mtcars, aes(mpg, wt)) +
  geom_point() +
  facet_wrap(~ cyl)

mean_wt <- data.frame(cyl = c(4, 6, 8), wt = c(2.28, 3.11, 4.00))

p + geom_hline(aes(yintercept = wt), mean_wt)
# Out:
# plot without title

# %%
# Other aesthetics can be controlled too

ggplot(mtcars, aes(mpg, wt, colour = wt)) +
  geom_point() +
  geom_hline(aes(yintercept = wt, colour = wt), mean_wt) +
  facet_wrap(~ cyl)
# Out:
# plot without title
